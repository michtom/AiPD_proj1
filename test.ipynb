# %%
import wave 
import matplotlib .pyplot as plt
import math
import numpy as np
import functions as af
import importlib

# %%
importlib.reload(af)
# Out:
# <module 'functions' from '/Users/danieltytkowski/Desktop/AiPD/functions.py'>

# %%
file = wave.open("test3.wav")
framerate = file.getframerate()

# %%
signal_array, n_frames = af.cut_file(file, 0, 12000)

# %%
n_frames/framerate
# Out:
# 12.0

# %%
window_len = af.get_window_len(file)
overlap_len = int(window_len/2)

# %%
overlap_len
# Out:
# 882

# %%
zcr = af.get_zcr(signal_array, window_len, overlap_len)
vol = af.get_volume(signal_array, window_len, overlap_len)

# %%
silence_array = af.cut_signal_array(signal_array, 10000, 12000, framerate)

# %%
silence = af.get_silence_frames(signal_array, silence_array, window_len, overlap_len, vol, zcr)

# %%
af.plot_signal(signal_array, zcr, vol, silence, None, framerate)
